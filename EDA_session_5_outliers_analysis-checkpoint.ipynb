# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r'C:\Users\SONY\Desktop\assignments\data_Files\Visadataset.csv')

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **non outliers data**

# %%
wage_data=visa_df['prevailing_wage']
q1=round(np.quantile(wage_data,0.25),2)
q3=round(np.quantile(wage_data,0.75),2)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=visa_df['prevailing_wage']>lb
con2=visa_df['prevailing_wage']<ub
con3=con1&con2
count=len(visa_df[con3])
non_outliers_data=visa_df[con3]
non_outliers_data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **how to treat outliers**

# %% [markdown]
# **method-1: drop the outliers**
#
# - if outliers has less than 2% of total data we can drop the outliers
#
# - droping the outliers is not a recommended approach
#
# - if we drop the outliers other columns data also drop
#
# - we encounter a situation that looses the data

# %% [markdown]
# **method-2**
#
# - we already know that ouliers does not affect by median
#
# - so it is always a good approach to fill outliers with median

# %% [markdown]
# **method-3**
#
# - instead of filling the outliers with median, we can fill with q3 and q1

# %%
# step-1: lb and ub
# step-2: calculate median
# step-3: new data=[]
# step-4: iterate ehc value from prevailing wage
# step-5: if that value <lb or >up
# step-6: new data.append(median)
# step-7: else:
# step-8: new data.append(value)
# step-9: visa_df['pwage']=new data

# %%
wage_data=visa_df['prevailing_wage']
q1=round(np.quantile(wage_data,0.25),2)
q3=round(np.quantile(wage_data,0.75),2)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
median=wage_data.median()
new_data=[]
for i in wage_data:
    if i<lb or i>ub:
        new_data.append(median)
    else:
        new_data.append(i)
visa_df['pwage']=new_data

# %%
import warnings
warnings.filterwarnings('ignore')
plt.subplot(2,1,1).hist(visa_df['pwage'])
plt.subplot(2,2,1).boxplot(visa_df['pwage'])
plt.show()

# %%
new_data=[]
for i in wage_data:
    if i<lb or i>ub:
        new_data.append(median)
    else:
        new_data.append(i)
visa_df['pwage']=new_data
new_data
# Out:
# [592.2029,
#  83425.65,
#  122996.86,
#  83434.03,
#  149907.39,
#  78252.14,
#  53635.39,
#  418.2298,
#  74362.19,
#  67514.76,
#  83588.56,
#  70813.09,
#  28663.05,
#  107196.03,
#  70308.20999999999,
#  74108.02,
#  3706.79,
#  16132.61,
#  150441.13,
#  79948.12,
#  71128.98,
#  137694.98,
#  45642.39,
#  90108.38,
#  71286.04,
#  99489.65,
#  86332.95,
#  103029.33,
#  40925.86,
#  189190.48,
#  79594.12,
#  135866.13,
#  72077.57,
#  81921.18,
#  70308.20999999999,
#  92421.92,
#  2490.12,
#  110817.26,
#  50960.01,
#  125336.9,
#  39633.32,
#  156326.33,
#  43630.58,
#  54614.42,
#  28989.87,
#  22924.91,
#  61567.75,
#  156251.17,
#  86022.02,
#  49565.37,
#  66191.41,
#  95623.2,
#  115014.05,
#  35018.04,
#  230.8072,
#  113799.64,
#  85854.09,
#  14174.04,
#  47176.84,
#  4949.28,
#  67410.59,
#  58791.58,
#  103.2216,
#  62591.57,
#  102919.59,
#  123468.56,
#  82324.64,
#  5319.49,
#  153019.94,
#  38059.89,
#  230.327,
#  61521.92,
#  121316.5,
#  122540.55,
# ...

# %% [markdown]
# **np.where**
#
# - np.where is a mehtod to do if-else task in single line
#
# - np.where(condition,TrueValue,FalseValue)
#
# - it takes 3 arguments
#
#     - condition
#
#     - if condition is True then it takes True value
#
#     - if conditon is Flase it takes false value

# %%
dict1={'marks':[100,200,300,400],
      'sub':['DS','DE','CS','IOT']}
df=pd.DataFrame(dict1)
df
# Out:
#    marks  sub
# 0    100   DS
# 1    200   DE
# 2    300   CS
# 3    400  IOT

# %%
# i want to replace marks=1 which are having >200
con=df['marks']>200
true=1
false=df['marks']
df['new']=np.where(con,true,false)
df
# Out:
#    marks  sub  new
# 0    100   DS  100
# 1    200   DE  200
# 2    300   CS    1
# 3    400  IOT    1

# %%
wage_data=visa_df['prevailing_wage']
q1=round(np.quantile(wage_data,0.25),2)
q3=round(np.quantile(wage_data,0.75),2)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
median=wage_data.median()
# replace outliers with median using np.where
con=(visa_df['prevailing_wage']<lb) | (visa_df['prevailing_wage']>ub)
true=median
false=visa_df['prevailing_wage']
visa_df['p_wage1']=np.where(con,true,false)

# %%
plt.boxplot(visa_df['p_wage1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b77e798280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b77e799ab0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b77e798bb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b77e798910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b77e7983d0>],
#  'means': []}
